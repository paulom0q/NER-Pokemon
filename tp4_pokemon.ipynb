# %%
import re
import json
from difflib import get_close_matches
import spacy
import nltk
from nltk.corpus import words
import random
from IPython.display import display, HTML
from spacy import displacy

# %%
# Déjà, je vais récuper tous les noms des pokémons pour corriger les typos du fichier NER-Pokemons.txt
# (Snorlx, Scyter, Garchommp et d'autres peut-être jsp.)
# https://github.com/sindresorhus/pokemon/blob/main/data/en.json
with open("all_pokemons.json", "r", encoding="utf-8") as file:
    all_pokemon_names = json.load(file)
#print(all_pokemon_names)

# %%
try:
    nltk.data.find('words')
except LookupError:
    nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\moqp3\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
# En gros là le but, c'est d'identifier les indices des caractères de la phrase, qui contiennent un nom de pokémon.
#{
#        "text": "Pikachu used Thunderbolt to defeat the wild Charmander",
#        "entities": [
#            [
#                0,
#                7,
#                "POKEMON"
#            ],
#            [
#                44,
#                54,
#                "POKEMON"
#            ]
#        ]
#    },
# De O à 7, on a pikachu, et de 44 à 54 on a charmander (salamèche)

# Liste des mots anglais
english_words = set(words.words())

# Liste des mots à exclure de la correction
exclude_words = ["shiny", "pokémon", "center"]

# Fonction pour corriger les fautes avec Levenshtein Distance
def correct_typo(word, pokemon_names, special_terms):
    if word.lower() in special_terms:
        return word.lower()
    
    # Vérifier si le mot est déjà un mot anglais
    if word.lower() in english_words:
        return word
    
    close_match = get_close_matches(word, pokemon_names, n=1, cutoff=0.8)
    
    # Correction uniquement si une correspondance proche est trouvée
    if close_match:
        return close_match[0]
    else:
        return word

# Fonction pour traiter et formater les données
def process_data(input_file, output_file, pokemon_names):
    json_data = []
    
    with open(input_file, 'r', encoding='utf-8') as file2:
        for line in file2:
            line = line.strip()
            if not line:
                continue

            # Extraction du texte
            match = re.match(r'^\d+\.\s*(.*)', line)
            if not match:
                continue
            extracted_text = match.group(1)

            # Utilisation de re.finditer pour capturer tous les mots, la ponctuation et les positions
            words_and_punctuation = list(re.finditer(r'\w+|[^\w\s]', extracted_text))

            corrected_text = []
            
            for item in words_and_punctuation:
                word = item.group(0)
                start_idx = item.start()
                end_idx = item.end()
                
                corrected_word = correct_typo(word, pokemon_names, exclude_words)
                corrected_text.append((corrected_word, start_idx, end_idx))

            # Reconstruction du texte et mise à jour des indices
            final_text = ""
            last_end = 0
            new_entities = []

            for corrected_word, start_idx, end_idx in corrected_text:
                final_text += extracted_text[last_end:start_idx] + corrected_word
                new_start_idx = len(final_text) - len(corrected_word)  # Nouvel index début
                new_end_idx = len(final_text)  # Nouvel index fin
                last_end = end_idx  # Met à jour la dernière position

                # Vérifier si c'est un Pokémon et ajouter les nouvelles coordonnées
                if corrected_word in pokemon_names:
                    new_entities.append([new_start_idx, new_end_idx, "POKEMON"])

            # Ajout de la dernière portion du texte après le dernier mot
            final_text += extracted_text[last_end:]

            # Sauvegarde des résultats dans le format json
            json_data.append({
                "text": final_text,
                "entities": new_entities
            })

    # Écriture du fichier JSON
    with open(output_file, 'w', encoding='utf-8') as outfile:
        json.dump(json_data, outfile, ensure_ascii=False, indent=4)

#entree = 'NER-Pokemons.txt'  
#sortie = 'formatted_pokemon_data.json'  
entree='larger_NER-Pokemons.txt'
sortie='larger_formatted_pokemon_data.json'
process_data(entree, sortie, all_pokemon_names)

# %%
# Ici une petite preuve que ça fonctionne correctement
def extract_pokemon_names(json_file):

    with open(json_file, 'r', encoding='utf-8') as file3:
        formated_data = json.load(file3)

    for line in formated_data:
        sentence = line['text']
        pokemons_entities = line['entities']

        print(f"Phrase étudiée : {sentence}")

        for entity in pokemons_entities:
            start_index = entity[0]
            end_index = entity[1]
            pokemon_name = sentence[start_index:end_index]
            print(f"  Nom du Pokémon : {pokemon_name}")

#extract_pokemon_names('formatted_pokemon_data.json')
extract_pokemon_names('larger_formatted_pokemon_data.json')
# Out:
# Phrase étudiée : Pikachu used Thunderbolt to defeat the wild Charmander.
#   Nom du Pokémon : Pikachu
#   Nom du Pokémon : Charmander
# Phrase étudiée : Ash's favorite pokémon is Charizard because of its powerful Flamethrower.
#   Nom du Pokémon : Charizard
# Phrase étudiée : Bulbasaur and Squirtle teamed up to battle against a wild Gengar.
#   Nom du Pokémon : Bulbasaur
#   Nom du Pokémon : Squirtle
#   Nom du Pokémon : Gengar
# Phrase étudiée : Team Rocket tried to capture Eevee, but it quickly escaped.
#   Nom du Pokémon : Eevee
# Phrase étudiée : Snorlax blocked the road, forcing the trainer to find another path.
#   Nom du Pokémon : Snorlax
# Phrase étudiée : Gyarados appeared from the water and scared all the nearby trainers.
#   Nom du Pokémon : Gyarados
# Phrase étudiée : Mewtwo is known as one of the most powerful legendary pokémon.
#   Nom du Pokémon : Mewtwo
# Phrase étudiée : Psyduck always has a headache, which makes it use Confuson randomly.
#   Nom du Pokémon : Psyduck
# Phrase étudiée : Jigglypuff sang a lullaby, putting everyone in the pokémon center to sleep.
#   Nom du Pokémon : Jigglypuff
# Phrase étudiée : Meowth from Team Rocket can talk like a human, which surprises many trainers.
#   Nom du Pokémon : Meowth
# Phrase étudiée : Blastoise used Hydro Pump to stop a raging fire in the forest.
#   Nom du Pokémon : Blastoise
# Phrase étudiée : Dragonite delivered a special message from Professor Oak.
#   Nom du Pokémon : Dragonite
# Phrase étudiée : Magikarp kept splashing in the water, but it eventually evolved into Gyarados.
#   Nom du Pokémon : Magikarp
#   Nom du Pokémon : Gyarados
# Phrase étudiée : Lucario sensed the aura of danger and warned its trainer.
#   Nom du Pokémon : Lucario
# Phrase étudiée : Alakazam’s psychic powers allow it to predict its opponent's next move.
#   Nom du Pokémon : Alakazam
# Phrase étudiée : Raichu is often overshadowed by Pikachu, but it has stronger electric attacks.
#   Nom du Pokémon : Raichu
#   Nom du Pokémon : Pikachu
# Phrase étudiée : A wild Tyranitar appeared in the mountains, causing a landslide.
#   Nom du Pokémon : Tyranitar
# Phrase étudiée : Scyther's sharp blades make it a fearsome opponent in battle.
#   Nom du Pokémon : Scyther
# Phrase étudiée : Lapras is often seen helping trainers cross large bodies of water.
#   Nom du Pokémon : Lapras
# Phrase étudiée : A shiny Umbreon was spotted during the full moon, surprising pokémon researchers.
#   Nom du Pokémon : Umbreon
# Phrase étudiée : Torchic evolved into Combusken after winning a battle against Mudkip.
#   Nom du Pokémon : Torchic
#   Nom du Pokémon : Combusken
#   Nom du Pokémon : Mudkip
# Phrase étudiée : The trainer caught a wild Squirtle near the river.
#   Nom du Pokémon : Squirtle
# Phrase étudiée : Gardevoir protected its trainer using Psychic against a wild Rhydon.
#   Nom du Pokémon : Gardevoir
#   Nom du Pokémon : Rhydon
# Phrase étudiée : A Dratini was seen swimming near the coast at sunset.
#   Nom du Pokémon : Dratini
# Phrase étudiée : Charizard flew across the sky, breathing fire in the shape of a dragon.
#   Nom du Pokémon : Charizard
# Phrase étudiée : The legendary Ho-oh was spotted flying over the mountains.
# Phrase étudiée : The Eeveelution of Vaporeon is known for its affinity with water.
#   Nom du Pokémon : Vaporeon
# Phrase étudiée : Cyndaquil used Flame Wheel to defeat a Bug-type opponent.
#   Nom du Pokémon : Cyndaquil
# Phrase étudiée : The trainer called out their strongest pokémon, Blaziken, to fight.
#   Nom du Pokémon : Blaziken
# Phrase étudiée : Mew can transform into any pokémon using its ability.
#   Nom du Pokémon : Mew
# Phrase étudiée : Electabuzz generates strong electricity by rubbing its body.
#   Nom du Pokémon : Electabuzz
# Phrase étudiée : A huge Snorlax was sleeping in the middle of the road.
#   Nom du Pokémon : Snorlax
# Phrase étudiée : The wild Zubat confused the opponent with Supersonic.
#   Nom du Pokémon : Zubat
# Phrase étudiée : The young trainer dreamed of catching an Articuno one day.
#   Nom du Pokémon : Articuno
# Phrase étudiée : Ash had a close battle with a skilled trainer using Gengar.
#   Nom du Pokémon : Gengar
# Phrase étudiée : The Pikachu in the wild was surprisingly strong.
#   Nom du Pokémon : Pikachu
# Phrase étudiée : Jolteon ran faster than the eye could see, dodging every attack.
#   Nom du Pokémon : Jolteon
# Phrase étudiée : Flareon’s fiery fur makes it warm even in cold places.
#   Nom du Pokémon : Flareon
# Phrase étudiée : A Swampert blocked the way with a powerful Earthquake.
#   Nom du Pokémon : Swampert
# Phrase étudiée : Someone reported seeing a rare Salamence in the forest.
#   Nom du Pokémon : Salamence
# Phrase étudiée : The legendary Rayquaza appeared in the stormy sky.
#   Nom du Pokémon : Rayquaza
# Phrase étudiée : Pidgeotto’s wings created powerful gusts of wind.
#   Nom du Pokémon : Pidgeotto
# Phrase étudiée : The trainer’s Espeon used Future Sight to predict the next attack.
#   Nom du Pokémon : Espeon
# Phrase étudiée : The opponent used a Flygon with incredible speed.
#   Nom du Pokémon : Flygon
# Phrase étudiée : Sableye’s glowing eyes were visible in the dark cave.
#   Nom du Pokémon : Sableye
# Phrase étudiée : The wild Gastly disappeared into the shadows.
#   Nom du Pokémon : Gastly
# Phrase étudiée : The fierce Garchomp roared, ready for battle.
#   Nom du Pokémon : Garchomp
# Phrase étudiée : A shiny Metagross was spotted at the pokémon tournament.
#   Nom du Pokémon : Metagross
# Phrase étudiée : Typhlosion’s flames burned brightly as it prepared to attack.
#   Nom du Pokémon : Typhlosion
# Phrase étudiée : The tiny Togepi danced happily in the trainer’s arms.
#   Nom du Pokémon : Togepi
# Phrase étudiée : A powerful Machamp defeated two opponents at once with its four arms.
#   Nom du Pokémon : Machamp
# Phrase étudiée : The trainer used a rare Ditto to mimic the opponent’s strongest pokémon.
#   Nom du Pokémon : Ditto
# Phrase étudiée : A mischievous Zorua transformed into the trainer’s Pikachu to cause confusion.
#   Nom du Pokémon : Zorua
#   Nom du Pokémon : Pikachu
# Phrase étudiée : The trainer’s Weavile used its sharp claws to slice through the opponent’s defenses.
#   Nom du Pokémon : Weavile
# Phrase étudiée : A majestic Lugia emerged from the ocean depths, creating a powerful tidal wave.
#   Nom du Pokémon : Lugia
# Phrase étudiée : The trainer’s Gallade used Psycho Cut to slice through the opponent’s attack.
#   Nom du Pokémon : Gallade
# Phrase étudiée : A wild Aggron charged through the forest, destroying everything in its path.
#   Nom du Pokémon : Aggron
# Phrase étudiée : The trainer’s Roserade used Petal Dance to create a beautiful and devastating attack.
#   Nom du Pokémon : Roserade
# Phrase étudiée : A mysterious Darkrai appeared in the trainer’s nightmares.
#   Nom du Pokémon : Darkrai
# Phrase étudiée : The trainer’s Gardevoir used Teleport to escape a dangerous situation.
#   Nom du Pokémon : Gardevoir
# Phrase étudiée : A rare Spiritomb was sealed inside an ancient keystone.
#   Nom du Pokémon : Spiritomb
# Phrase étudiée : The trainer’s Absol warned of an impending disaster with its ability to sense danger.
#   Nom du Pokémon : Absol
# Phrase étudiée : A giant Wailord surfaced near the shore, surprising the beachgoers.
#   Nom du Pokémon : Wailord
# Phrase étudiée : The trainer’s Staraptor soared through the sky, scouting the area.
#   Nom du Pokémon : Staraptor
# Phrase étudiée : A cunning Ninetales used its illusions to trick its opponents.
#   Nom du Pokémon : Ninetales
# Phrase étudiée : The trainer’s Luxray used its X-ray vision to find hidden objects.
#   Nom du Pokémon : Luxray
# Phrase étudiée : A powerful Metagross used Meteor Mash to crush its opponent.
#   Nom du Pokémon : Metagross
# Phrase étudiée : The trainer’s Infernape used Flare Blitz to ignite the battlefield.
#   Nom du Pokémon : Infernape
# Phrase étudiée : A mischievous Gible nipped at the trainer’s heels.
#   Nom du Pokémon : Gible
# Phrase étudiée : The trainer’s Garchomp used Dragon Rush to devastate the opponent’s team.
#   Nom du Pokémon : Garchomp
# Phrase étudiée : A legendary Giratina appeared in a distortion world.
#   Nom du Pokémon : Giratina
# Phrase étudiée : The trainer’s Empoleon used Hydro Cannon to blast away the foe.
#   Nom du Pokémon : Empoleon
# Phrase étudiée : A playful Piplup slid across the icy terrain.
#   Nom du Pokémon : Piplup
# Phrase étudiée : The trainer’s Torterra used Earthquake to shake the entire arena.
#   Nom du Pokémon : Torterra
# Phrase étudiée : A wild Hippowdon created a sandstorm, blinding the trainers.
#   Nom du Pokémon : Hippowdon
# Phrase étudiée : The trainer’s Crobat used its supersonic waves to confuse the enemy.
#   Nom du Pokémon : Crobat
# Phrase étudiée : A rare Bronzong rang its bell, creating a psychic wave.
#   Nom du Pokémon : Bronzong
# Phrase étudiée : The trainer’s Drapion used Cross Poison to inflict a deadly attack.
#   Nom du Pokémon : Drapion
# Phrase étudiée : A wild Tangrowth wrapped its vines around the trainer, trapping them.
#   Nom du Pokémon : Tangrowth
# Phrase étudiée : The trainer’s Yanmega used Ancient Power to unleash a barrage of attacks.
#   Nom du Pokémon : Yanmega
# Phrase étudiée : A powerful Rhyperior used Rock Wrecker to destroy the opponent's defenses.
#   Nom du Pokémon : Rhyperior
# Phrase étudiée : The trainer’s Mamoswine used Ice Fang to freeze the opponent solid.
#   Nom du Pokémon : Mamoswine
# Phrase étudiée : A legendary Cresselia appeared during the full moon, granting peaceful dreams.
#   Nom du Pokémon : Cresselia
# Phrase étudiée : The trainer’s Gliscor used Acrobatics to avoid attacks and strike back.
#   Nom du Pokémon : Gliscor
# Phrase étudiée : A wild Dusknoir used Shadow Punch to attack from the darkness.
#   Nom du Pokémon : Dusknoir
# Phrase étudiée : The trainer’s Froslass used Ice Beam to create a frozen barrier.
#   Nom du Pokémon : Froslass
# Phrase étudiée : A rare Rotom changed forms, becoming a powerful appliance pokémon.
#   Nom du Pokémon : Rotom
# Phrase étudiée : The trainer’s Uxie shared its wisdom with the other pokémon.
#   Nom du Pokémon : Uxie
# Phrase étudiée : A legendary Mesprit appeared in the center of the lake, granting emotions.
#   Nom du Pokémon : Mesprit
# Phrase étudiée : The trainer’s Azelf used its willpower to overcome any obstacle.
#   Nom du Pokémon : Azelf
# Phrase étudiée : A powerful Dialga controlled time during the battle.
#   Nom du Pokémon : Dialga
# Phrase étudiée : Palkia warped space to confuse the opponent.
#   Nom du Pokémon : Palkia
# Phrase étudiée : Regigigas woke up from a long slumber and started to move.
#   Nom du Pokémon : Regigigas
# Phrase étudiée : Giratina altered the reality of the battlefield.
#   Nom du Pokémon : Giratina
# Phrase étudiée : Arceus used its power to change its type to counter the opponent.
#   Nom du Pokémon : Arceus
# Phrase étudiée : Zacian used its sword to cut through any defense.
#   Nom du Pokémon : Zacian
# Phrase étudiée : Zamazenta used its shield to protect itself from any attack.
#   Nom du Pokémon : Zamazenta
# Phrase étudiée : Eternatus unleashed its power, causing chaos around it.
#   Nom du Pokémon : Eternatus
# Phrase étudiée : Calyrex rode on Glastrier, freezing the surroundings.
#   Nom du Pokémon : Calyrex
#   Nom du Pokémon : Glastrier
# Phrase étudiée : Calyrex rode on Spectrier, creating shadows and confusion.
#   Nom du Pokémon : Calyrex
#   Nom du Pokémon : Spectrier
# Phrase étudiée : A young trainer found a hidden cave with a rare Larvitar.
#   Nom du Pokémon : Larvitar
# Phrase étudiée : A group of trainers battled against a massive Onix in the rocky canyon.
#   Nom du Pokémon : Onix
# Phrase étudiée : A wild Skarmory soared through the skies, its metallic wings gleaming.
#   Nom du Pokémon : Skarmory
# Phrase étudiée : The trainer used a powerful Houndoom to track down a lost pokémon.
#   Nom du Pokémon : Houndoom
# Phrase étudiée : A mischievous Murkrow stole the trainer’s hat and flew away.
#   Nom du Pokémon : Murkrow
# Phrase étudiée : The trainer’s Kingdra used Hydro Pump to extinguish a forest fire.
#   Nom du Pokémon : Kingdra
# Phrase étudiée : A wild Donphan charged through the desert, kicking up sand and dust.
#   Nom du Pokémon : Donphan
# Phrase étudiée : The trainer’s Porygon2 used Conversion2 to change its type and resist attacks.
#   Nom du Pokémon : Porygon2
# Phrase étudiée : A rare Stantler appeared in the snowy forest, its Stantler glowing in the moonlight.
#   Nom du Pokémon : Stantler
#   Nom du Pokémon : Stantler
# Phrase étudiée : The trainer’s Hitmontop used Triple Kick to defeat a powerful opponent.
#   Nom du Pokémon : Hitmontop
# Phrase étudiée : A wild Smoochum blew icy kisses, freezing the trainer in place.
#   Nom du Pokémon : Smoochum
# Phrase étudiée : The trainer’s Miltank used Milk Drink to heal its wounds after a tough battle.
#   Nom du Pokémon : Miltank
# Phrase étudiée : A playful Blissey helped heal injured pokémon at the pokémon center.
#   Nom du Pokémon : Blissey
# Phrase étudiée : The trainer’s Raikou unleashed a powerful Thunder attack, shocking the entire arena.
#   Nom du Pokémon : Raikou
# Phrase étudiée : A majestic Entei roared, its fiery mane blazing like the sun.
#   Nom du Pokémon : Entei
# Phrase étudiée : A graceful Suicune glided across the water, its crystal-clear body shimmering.
#   Nom du Pokémon : Suicune
# Phrase étudiée : The trainer’s Tyranitar used Hyper Beam to destroy a giant boulder.
#   Nom du Pokémon : Tyranitar
# Phrase étudiée : A rare Lugia appeared from the depths of the ocean, its wings creating a powerful storm.
#   Nom du Pokémon : Lugia
# Phrase étudiée : The trainer’s Ho-Oh soared through the sky, its rainbow wings leaving a trail of light.
# Phrase étudiée : A mischievous Celebi traveled through time, causing strange events in the forest.
#   Nom du Pokémon : Celebi
# Phrase étudiée : The trainer's Treecko used Quick Attack to dodge the opponent's strike.
#   Nom du Pokémon : Treecko
# Phrase étudiée : A wild Torchic pecked at the trainer's shoes, demanding attention.
#   Nom du Pokémon : Torchic
# Phrase étudiée : The trainer's Mudkip used Water Gun to create a muddy puddle.
#   Nom du Pokémon : Mudkip
# Phrase étudiée : A playful Poochyena chased its tail, spinning in circles.
#   Nom du Pokémon : Poochyena
# Phrase étudiée : The trainer's Zigzagoon found a hidden item in the tall grass.
#   Nom du Pokémon : Zigzagoon
# Phrase étudiée : A wild Wurmple wiggled its way through the leaves.
#   Nom du Pokémon : Wurmple
# Phrase étudiée : The trainer's Lotad danced on the water's surface, its lilypad swaying.
#   Nom du Pokémon : Lotad
# Phrase étudiée : A mischievous Seedot dropped acorns on the trainer's head.
#   Nom du Pokémon : Seedot
# Phrase étudiée : The trainer's Taillow soared through the sky, scouting the area.
#   Nom du Pokémon : Taillow
# Phrase étudiée : A wild Wingull squawked as it flew overhead.
#   Nom du Pokémon : Wingull
# Phrase étudiée : The trainer's Ralts used Teleport to escape a dangerous situation.
#   Nom du Pokémon : Ralts
# Phrase étudiée : A playful Surskit skated across the water's surface.
#   Nom du Pokémon : Surskit
# Phrase étudiée : The trainer's Shroomish used Mega Drain to absorb the opponent's energy.
#   Nom du Pokémon : Shroomish
# Phrase étudiée : A wild Slakoth lazed in the sun, taking a nap.
#   Nom du Pokémon : Slakoth
# Phrase étudiée : The trainer's Nincada burrowed underground, disappearing from sight.
#   Nom du Pokémon : Nincada
# Phrase étudiée : A mischievous Whismur whispered loudly, startling the trainer.
#   Nom du Pokémon : Whismur
# Phrase étudiée : The trainer's Loudred used Echoed Voice to amplify its attack.
#   Nom du Pokémon : Loudred
# Phrase étudiée : A wild Makuhita charged forward, ready to battle.
#   Nom du Pokémon : Makuhita
# Phrase étudiée : The trainer's Nosepass pointed its nose towards a hidden treasure.
#   Nom du Pokémon : Nosepass
# Phrase étudiée : A playful Skitty chased its tail, rolling around in the grass.
#   Nom du Pokémon : Skitty
# Phrase étudiée : The trainer's Delcatty used Attract to charm the opponent.
#   Nom du Pokémon : Delcatty
# Phrase étudiée : A wild Sableye grinned mischievously, its eyes glowing in the dark.
#   Nom du Pokémon : Sableye
# Phrase étudiée : The trainer's Mawile used Iron Head to crush the opponent's defenses.
#   Nom du Pokémon : Mawile
# Phrase étudiée : A playful Aron headbutted a rock, showing off its strength.
#   Nom du Pokémon : Aron
# Phrase étudiée : The trainer's Lairon used Metal Claw to slash through the opponent's attack.
#   Nom du Pokémon : Lairon
# Phrase étudiée : A wild Lileep swayed in the water, its tentacles reaching out.
#   Nom du Pokémon : Lileep
# Phrase étudiée : The trainer's Anorith used Ancient Power to unleash a barrage of attacks.
#   Nom du Pokémon : Anorith
# Phrase étudiée : A playful Spheal rolled around in the snow, having fun.
#   Nom du Pokémon : Spheal
# Phrase étudiée : The trainer's Sealeo used Body Slam to crush the opponent.
#   Nom du Pokémon : Sealeo
# Phrase étudiée : A wild Walrein bellowed loudly, its tusks gleaming in the sun.
#   Nom du Pokémon : Walrein
# Phrase étudiée : A wild Relicanth emerged from the deep sea, its ancient body covered in barnacles.
#   Nom du Pokémon : Relicanth
# Phrase étudiée : The trainer's Metang floated through the air, its metallic body gleaming in the sunlight.
#   Nom du Pokémon : Metang
# Phrase étudiée : A mischievous Bagon tried to fly, but it kept falling to the ground.
#   Nom du Pokémon : Bagon
# Phrase étudiée : The trainer's Shelgon protected itself with its hard shell, deflecting the opponent's attacks.
#   Nom du Pokémon : Shelgon
# Phrase étudiée : A powerful Salamence soared through the sky, its wings creating a powerful gust of wind.
#   Nom du Pokémon : Salamence
# Phrase étudiée : The trainer's Beldum used Take Down to tackle the opponent.
#   Nom du Pokémon : Beldum
# Phrase étudiée : A rare Metagross appeared at the pokémon League, its four brains working in unison.
#   Nom du Pokémon : Metagross
# Phrase étudiée : The trainer's Regirock unleashed a powerful Rock Throw, sending the opponent flying.
#   Nom du Pokémon : Regirock
# Phrase étudiée : A legendary Regice emerged from a frozen cave, its body made of solid ice.
#   Nom du Pokémon : Regice
# Phrase étudiée : The trainer's Registeel used Iron Defense to harden its body, becoming impervious to attacks.
#   Nom du Pokémon : Registeel
# Phrase étudiée : A mysterious Latias flew over the city, its psychic powers protecting the citizens.
#   Nom du Pokémon : Latias
# Phrase étudiée : The trainer's Latios soared through the sky, its speed unmatched by any other pokémon.
#   Nom du Pokémon : Latios
# Phrase étudiée : A legendary Kyogre emerged from the ocean depths, its power creating a massive storm.
#   Nom du Pokémon : Kyogre
# Phrase étudiée : The trainer's Groudon unleashed a powerful Earthquake, shaking the entire region.
#   Nom du Pokémon : Groudon
# Phrase étudiée : A majestic Rayquaza descended from the sky, its presence calming the raging storm.
#   Nom du Pokémon : Rayquaza
# Phrase étudiée : The trainer's Jirachi granted a wish, its star-shaped body glowing brightly.
#   Nom du Pokémon : Jirachi
# Phrase étudiée : A playful Deoxys changed forms, confusing the opponent with its unpredictable attacks.
#   Nom du Pokémon : Deoxys
# Phrase étudiée : The trainer's Turtwig used Absorb to heal itself, draining the opponent's energy.
#   Nom du Pokémon : Turtwig
# Phrase étudiée : A wild Chimchar climbed a tree, its fiery tail burning brightly.
#   Nom du Pokémon : Chimchar
# Phrase étudiée : The trainer's Piplup used Bubble Beam to create a dazzling display of bubbles.
#   Nom du Pokémon : Piplup
# Phrase étudiée : A mischievous Starly pecked at the trainer's hair, searching for food.
#   Nom du Pokémon : Starly
# Phrase étudiée : The trainer's Bidoof used Super Fang to bite through the opponent's defenses.
#   Nom du Pokémon : Bidoof
# Phrase étudiée : A playful Kricketot chirped happily, its sound echoing through the forest.
#   Nom du Pokémon : Kricketot
# Phrase étudiée : The trainer's Kricketune played a beautiful melody, mesmerizing the audience.
#   Nom du Pokémon : Kricketune
# Phrase étudiée : A wild Shinx sparked with electricity, its fur crackling with energy.
#   Nom du Pokémon : Shinx
# Phrase étudiée : The trainer's Luxio used Spark to shock the opponent.
#   Nom du Pokémon : Luxio
# Phrase étudiée : A powerful Luxray used Thunder Fang to bite down on the opponent.
#   Nom du Pokémon : Luxray
# Phrase étudiée : The trainer's Empoleon used Hydro Cannon to blast away the foe.
#   Nom du Pokémon : Empoleon
# Phrase étudiée : A playful Budew danced in the sunlight, its flower petals swaying gently.
#   Nom du Pokémon : Budew
# Phrase étudiée : The trainer's Roselia used Magical Leaf to create a swirling vortex of leaves.
#   Nom du Pokémon : Roselia
# Phrase étudiée : A beautiful Roserade used Petal Dance to create a mesmerizing display of flowers.
#   Nom du Pokémon : Roserade
# Phrase étudiée : The trainer's Cranidos used Headbutt to smash through the opponent's defenses.
#   Nom du Pokémon : Cranidos
# Phrase étudiée : A wild Shieldon protected itself with its sturdy shield, deflecting the opponent's attacks.
#   Nom du Pokémon : Shieldon
# Phrase étudiée : The trainer's Bastiodon used Iron Head to crush the opponent's defenses.
#   Nom du Pokémon : Bastiodon
# Phrase étudiée : A mischievous Burmy hid in its cloak, blending in with its surroundings.
#   Nom du Pokémon : Burmy
# Phrase étudiée : The trainer's Wormadam used Bug Bite to drain the opponent's energy.
#   Nom du Pokémon : Wormadam
# Phrase étudiée : A beautiful Mothim fluttered its wings, creating a gentle breeze.
#   Nom du Pokémon : Mothim
# Phrase étudiée : The trainer's Combee buzzed around, collecting honey from flowers.
#   Nom du Pokémon : Combee
# Phrase étudiée : A majestic Vespiquen commanded its Combee, its power unmatched by any other pokémon.
#   Nom du Pokémon : Vespiquen
#   Nom du Pokémon : Combee
# Phrase étudiée : The trainer's Pachirisu used Discharge to shock the opponent.
#   Nom du Pokémon : Pachirisu
# Phrase étudiée : A playful Buizel swam through the water, its tail propelling it forward.
#   Nom du Pokémon : Buizel
# Phrase étudiée : The trainer's Floatzel used Aqua Jet to speed through the water.
#   Nom du Pokémon : Floatzel
# Phrase étudiée : A mischievous Cherubi dropped berries on the trainer's head.
#   Nom du Pokémon : Cherubi
# Phrase étudiée : The trainer's Cherrim changed forms, blooming into a beautiful flower.
#   Nom du Pokémon : Cherrim
# Phrase étudiée : A playful Shellos left a trail of slime as it crawled along the ground.
#   Nom du Pokémon : Shellos
# Phrase étudiée : The trainer's Gastrodon used Muddy Water to create a slippery surface.
#   Nom du Pokémon : Gastrodon
# Phrase étudiée : A mischievous Ambipom used Double Hit to strike the opponent twice.
#   Nom du Pokémon : Ambipom
# Phrase étudiée : The trainer's Drifloon floated through the air, carrying the trainer away.
#   Nom du Pokémon : Drifloon
# Phrase étudiée : A mysterious Drifblim drifted through the sky, its presence causing strange events.
#   Nom du Pokémon : Drifblim
# Phrase étudiée : The trainer's Buneary used Ice Punch to freeze the opponent solid.
#   Nom du Pokémon : Buneary
# Phrase étudiée : Word has it, a rare Eevee was spotted deep in the forest, shifting through its many evolutions.
#   Nom du Pokémon : Eevee
# Phrase étudiée : Out of nowhere, a massive Snorlax blocked the road, halting trainers in their tracks.
#   Nom du Pokémon : Snorlax
# Phrase étudiée : From the depths, a majestic Gyarados emerged, Ursaring the wits out of nearby fishermen.
#   Nom du Pokémon : Gyarados
#   Nom du Pokémon : Ursaring
# Phrase étudiée : Legend speaks of Mewtwo, one of the most powerful pokémon, dwelling in a hidden cave.
#   Nom du Pokémon : Mewtwo
# Phrase étudiée : They say Psyduck, with its constant headaches, uses Confusion in unpredictable ways.
#   Nom du Pokémon : Psyduck
# Phrase étudiée : At the pokémon center, Jigglypuff sang a lullaby, putting everyone to sleep.
#   Nom du Pokémon : Jigglypuff
# Phrase étudiée : Unbelievable! Meowth from Team Rocket talks like a human, surprising anyone who hears it.
#   Nom du Pokémon : Meowth
# Phrase étudiée : Blastoise was the one who used Hydro Pump to extinguish a forest fire.
#   Nom du Pokémon : Blastoise
# Phrase étudiée : Rumor has it, Dragonite delivered an important message from Professor Oak.
#   Nom du Pokémon : Dragonite
# Phrase étudiée : They say Magikarp, by splashing around relentlessly, finally evolved into Gyarados.
#   Nom du Pokémon : Magikarp
#   Nom du Pokémon : Gyarados
# Phrase étudiée : With its psychic powers, Alakazam can foresee its opponent's next move.
#   Nom du Pokémon : Alakazam
# Phrase étudiée : Though often overshadowed by Pikachu, Raichu packs a stronger electric punch.
#   Nom du Pokémon : Pikachu
#   Nom du Pokémon : Raichu
# Phrase étudiée : A wild Tyranitar caused a landslide when it appeared in the mountains.
#   Nom du Pokémon : Tyranitar
# Phrase étudiée : With its razor-sharp blades, Scyther is a formidable foe in battle.
#   Nom du Pokémon : Scyther
# Phrase étudiée : More often than not, Lapras helps trainers cross vast bodies of water.
#   Nom du Pokémon : Lapras
# Phrase étudiée : During the full moon, a shiny Umbreon was spotted, startling pokémon researchers.
#   Nom du Pokémon : Umbreon
# Phrase étudiée : After winning a battle against Mudkip, Torchic evolved into Combusken.
#   Nom du Pokémon : Mudkip
#   Nom du Pokémon : Torchic
#   Nom du Pokémon : Combusken
# Phrase étudiée : Near the river, a wild Squirtle was caught by a trainer.
#   Nom du Pokémon : Squirtle
# Phrase étudiée : Using Psychic, Gardevoir protected its trainer from a wild Rhydon.
#   Nom du Pokémon : Gardevoir
#   Nom du Pokémon : Rhydon
# Phrase étudiée : At sunset, a Dratini was seen swimming near the coast.
#   Nom du Pokémon : Dratini
# Phrase étudiée : Soaring through the sky, Charizard breathed fire in the shape of a dragon.
#   Nom du Pokémon : Charizard
# Phrase étudiée : Legend has it, Ho-Oh was spotted flying over the mountains.
# Phrase étudiée : Vaporeon, an Eevee evolution, is known for its affinity with water.
#   Nom du Pokémon : Vaporeon
#   Nom du Pokémon : Eevee
# Phrase étudiée : To defeat a Bug-type opponent, Cyndaquil used Flame Wheel.
#   Nom du Pokémon : Cyndaquil
# Phrase étudiée : To fight, the trainer called upon their strongest pokémon, Blaziken.
#   Nom du Pokémon : Blaziken
# Phrase étudiée : Thanks to its ability, Mew can transform into any pokémon.
#   Nom du Pokémon : Mew
# Phrase étudiée : By rubbing its body, Electabuzz generates powerful electricity.
#   Nom du Pokémon : Electabuzz
# Phrase étudiée : A huge Snorlax was sleeping right in the middle of the road.
#   Nom du Pokémon : Snorlax
# Phrase étudiée : With Supersonic, a wild Zubat confused its opponent.
#   Nom du Pokémon : Zubat
# Phrase étudiée : The young trainer dreamed of catching Articuno one day.
#   Nom du Pokémon : Articuno
# Phrase étudiée : A fierce battle pitted Ash against a skilled trainer using Gengar.
#   Nom du Pokémon : Gengar
# Phrase étudiée : In the wild, a Pikachu proved surprisingly strong.
#   Nom du Pokémon : Pikachu
# Phrase étudiée : Faster than lightning, Jolteon dodged every attack.
#   Nom du Pokémon : Jolteon
# Phrase étudiée : Even in cold places, Flareon's fiery fur keeps it warm.
#   Nom du Pokémon : Flareon
# Phrase étudiée : With Earthquake, a Swampert blocked the path.
#   Nom du Pokémon : Swampert
# Phrase étudiée : In the forest, a rare Salamence was reportedly seen.
#   Nom du Pokémon : Salamence
# Phrase étudiée : Amidst a stormy sky, Rayquaza appeared.
#   Nom du Pokémon : Rayquaza
# Phrase étudiée : Pidgeot's wings created powerful gusts of wind.
#   Nom du Pokémon : Pidgeot
# Phrase étudiée : Thanks to Future Sight, the trainer's Espeon anticipated the next attack.
#   Nom du Pokémon : Espeon
# Phrase étudiée : An opponent used a Flygon with incredible speed.
#   Nom du Pokémon : Flygon
# Phrase étudiée : In the dark cave, Sableye's glowing eyes were visible.
#   Nom du Pokémon : Sableye
# Phrase étudiée : A wild Gastly vanished into the shadows.
#   Nom du Pokémon : Gastly
# Phrase étudiée : Ready for battle, Garchomp roared fiercely.
#   Nom du Pokémon : Garchomp
# Phrase étudiée : At the pokémon tournament, a shiny Metagross was spotted.
#   Nom du Pokémon : Metagross
# Phrase étudiée : Typhlosion's flames burned intensely as it prepared to attack.
#   Nom du Pokémon : Typhlosion
# Phrase étudiée : In the trainer's arms, a tiny Togepi danced joyfully.
#   Nom du Pokémon : Togepi
# Phrase étudiée : With its four arms, Machamp defeated two opponents at once.
#   Nom du Pokémon : Machamp
# Phrase étudiée : To mimic the opponent's strongest pokémon, the trainer used a rare Ditto.
#   Nom du Pokémon : Ditto
# Phrase étudiée : To cause confusion, a mischievous Zorua transformed into Pikachu.
#   Nom du Pokémon : Zorua
#   Nom du Pokémon : Pikachu
# Phrase étudiée : With its sharp claws, Weavile sliced through the opponent's defenses.
#   Nom du Pokémon : Weavile
# Phrase étudiée : It's said that a wild Lickitung can extend its tongue to incredible lengths.
#   Nom du Pokémon : Lickitung
# Phrase étudiée : A trainer once encountered a Tangela that had vines covering its entire body.
#   Nom du Pokémon : Tangela
# Phrase étudiée : Nobody expected to see a Kangaskhan protecting its baby in the tall grass.
#   Nom du Pokémon : Kangaskhan
# Phrase étudiée : A Seadra was spotted performing a mesmerizing dance on the water's surface.
#   Nom du Pokémon : Seadra
# Phrase étudiée : Word spread about a Goldeen that could control the flow of water with its horn.
#   Nom du Pokémon : Goldeen
# Phrase étudiée : A trainer discovered a Staryu glowing brightly in the depths of the ocean.
#   Nom du Pokémon : Staryu
# Phrase étudiée : It was rumored that a Mr. Mime could create invisible walls with its pantomime skills.
# Phrase étudiée : A Scyther was seen gracefully leaping through the trees, its blades gleaming.
#   Nom du Pokémon : Scyther
# Phrase étudiée : People talked about a Jynx that could sing enchanting melodies to lull its opponents.
#   Nom du Pokémon : Jynx
# Phrase étudiée : A trainer was amazed to see an Electabuzz generating electricity from its plugs.
#   Nom du Pokémon : Electabuzz
# Phrase étudiée : It was said that a Magmar could control flames with its fiery body.
#   Nom du Pokémon : Magmar
# Phrase étudiée : A Pinsir was spotted using its horns to lift heavy objects with ease.
#   Nom du Pokémon : Pinsir
# Phrase étudiée : Nobody believed that a Tauros could charge with incredible speed and power.
#   Nom du Pokémon : Tauros
# Phrase étudiée : A trainer found a Magikarp that could splash higher than any other.
#   Nom du Pokémon : Magikarp
# Phrase étudiée : It was rumored that a Lapras could carry people across the sea on its back.
#   Nom du Pokémon : Lapras
# Phrase étudiée : People were amazed to see a Ditto transform into a perfect copy of a legendary pokémon.
#   Nom du Pokémon : Ditto
# Phrase étudiée : A trainer encountered an Eevee that could evolve into any of its forms at will.
#   Nom du Pokémon : Eevee
# Phrase étudiée : It was said that a Porygon could travel through cyberspace with its digital body.
#   Nom du Pokémon : Porygon
# Phrase étudiée : A trainer discovered an Omanyte fossil and brought it back to life.
#   Nom du Pokémon : Omanyte
# Phrase étudiée : It was rumored that an Omastar could crush its opponents with its hard shell.
#   Nom du Pokémon : Omastar
# Phrase étudiée : People talked about a Kabuto that could glide across the water's surface.
#   Nom du Pokémon : Kabuto
# Phrase étudiée : A trainer found a Kabutops that could slash through anything with its scythes.
#   Nom du Pokémon : Kabutops
# Phrase étudiée : It was said that an Aerodactyl could soar through the sky with its powerful wings.
#   Nom du Pokémon : Aerodactyl
# Phrase étudiée : A trainer was amazed to see a Snorlax eat an entire forest's worth of food.
#   Nom du Pokémon : Snorlax
# Phrase étudiée : It was rumored that an Articuno could create blizzards with its icy wings.
#   Nom du Pokémon : Articuno
# Phrase étudiée : People talked about a Zapdos that could summon thunderstorms with its electric powers.
#   Nom du Pokémon : Zapdos
# Phrase étudiée : A trainer encountered a Moltres that could set entire forests ablaze with its fiery wings.
#   Nom du Pokémon : Moltres
# Phrase étudiée : It was said that a Dratini could shed its skin to grow larger and stronger.
#   Nom du Pokémon : Dratini
# Phrase étudiée : A trainer discovered a Dragonair that could control the weather with its mystical powers.
#   Nom du Pokémon : Dragonair
# Phrase étudiée : It was rumored that a Dragonite could fly around the world in just sixteen hours.
#   Nom du Pokémon : Dragonite
# Phrase étudiée : People were amazed to see a Mewtwo create psychic storms with its mind.
#   Nom du Pokémon : Mewtwo
# Phrase étudiée : A trainer encountered a Mew that could transform into any pokémon and use any move.
#   Nom du Pokémon : Mew
# Phrase étudiée : It was said that a Chikorita could heal others with the leaf on its head.
#   Nom du Pokémon : Chikorita
# Phrase étudiée : A trainer found a Bayleef that could control plants with its leafy neck.
#   Nom du Pokémon : Bayleef
# Phrase étudiée : It was rumored that a Meganium could create healing fields with its flower.
#   Nom du Pokémon : Meganium
# Phrase étudiée : People talked about a Cyndaquil that could ignite its back with flames.
#   Nom du Pokémon : Cyndaquil
# Phrase étudiée : A trainer encountered a Quilava that could unleash fiery explosions with its body.
#   Nom du Pokémon : Quilava
# Phrase étudiée : It was said that a Typhlosion could create volcanic eruptions with its power.
#   Nom du Pokémon : Typhlosion
# Phrase étudiée : A trainer discovered a Totodile that could bite with incredible force.
#   Nom du Pokémon : Totodile
# Phrase étudiée : It was rumored that a Croconaw could snap its jaws with enough power to crush rocks.
#   Nom du Pokémon : Croconaw
# Phrase étudiée : People were amazed to see a Feraligatr that could swim through any body of water.
#   Nom du Pokémon : Feraligatr
# Phrase étudiée : A trainer encountered a Sentret that could stand on its tail to see long distances.
#   Nom du Pokémon : Sentret
# Phrase étudiée : It was said that a Furret could squeeze through any narrow space with its flexible body.
#   Nom du Pokémon : Furret
# Phrase étudiée : A trainer found a Hoothoot that could tell the time with its internal clock.
#   Nom du Pokémon : Hoothoot
# Phrase étudiée : It was rumored that a Noctowl could see in complete darkness with its sharp eyes.
#   Nom du Pokémon : Noctowl
# Phrase étudiée : People talked about a Ledyba that could communicate with others through its antennae.
#   Nom du Pokémon : Ledyba
# Phrase étudiée : A trainer encountered a Ledian that could unleash powerful punches with its armored fists.
#   Nom du Pokémon : Ledian
# Phrase étudiée : Legend says that Gallade is the author's favorite pokémon.
#   Nom du Pokémon : Gallade
# Phrase étudiée : To cause confusion, a mischievous Zorua transformed into Pikachu.
#   Nom du Pokémon : Zorua
#   Nom du Pokémon : Pikachu
# Phrase étudiée : With its sharp claws, Weavile sliced through the opponent's defenses.
#   Nom du Pokémon : Weavile
# Phrase étudiée : It's said that a wild Lickitung can extend its tongue to incredible lengths.
#   Nom du Pokémon : Lickitung
# Phrase étudiée : A trainer once encountered a Tangela that had vines covering its entire body.
#   Nom du Pokémon : Tangela
# Phrase étudiée : Nobody expected to see a Kangaskhan protecting its baby in the tall grass.
#   Nom du Pokémon : Kangaskhan
# Phrase étudiée : A Seadra was spotted performing a mesmerizing dance on the water's surface.
#   Nom du Pokémon : Seadra
# Phrase étudiée : Word spread about a Goldeen that could control the flow of water with its horn.
#   Nom du Pokémon : Goldeen
# Phrase étudiée : A trainer discovered a Staryu glowing brightly in the depths of the ocean.
#   Nom du Pokémon : Staryu
# Phrase étudiée : It was rumored that a Mr. Mime could create invisible walls with its pantomime skills.
# Phrase étudiée : A Scyther was seen gracefully leaping through the trees, its blades gleaming.
#   Nom du Pokémon : Scyther
# Phrase étudiée : People talked about a Jynx that could sing enchanting melodies to lull its opponents.
#   Nom du Pokémon : Jynx
# Phrase étudiée : A trainer was amazed to see an Electabuzz generating electricity from its plugs.
#   Nom du Pokémon : Electabuzz
# Phrase étudiée : It was said that a Magmar could control flames with its fiery body.
#   Nom du Pokémon : Magmar
# Phrase étudiée : A Pinsir was spotted using its horns to lift heavy objects with ease.
#   Nom du Pokémon : Pinsir
# Phrase étudiée : Nobody believed that a Tauros could charge with incredible speed and power.
#   Nom du Pokémon : Tauros
# Phrase étudiée : A trainer found a Magikarp that could splash higher than any other.
#   Nom du Pokémon : Magikarp
# Phrase étudiée : It was rumored that a Lapras could carry people across the sea on its back.
#   Nom du Pokémon : Lapras
# Phrase étudiée : People were amazed to see a Ditto transform into a perfect copy of a legendary pokémon.
#   Nom du Pokémon : Ditto
# Phrase étudiée : A trainer encountered an Eevee that could evolve into any of its forms at will.
#   Nom du Pokémon : Eevee
# Phrase étudiée : It was said that a Porygon could travel through cyberspace with its digital body.
#   Nom du Pokémon : Porygon
# Phrase étudiée : A trainer discovered an Omanyte fossil and brought it back to life.
#   Nom du Pokémon : Omanyte
# Phrase étudiée : It was rumored that an Omastar could crush its opponents with its hard shell.
#   Nom du Pokémon : Omastar
# Phrase étudiée : People talked about a Kabuto that could glide across the water's surface.
#   Nom du Pokémon : Kabuto
# Phrase étudiée : A trainer found a Kabutops that could slash through anything with its scythes.
#   Nom du Pokémon : Kabutops
# Phrase étudiée : It was said that an Aerodactyl could soar through the sky with its powerful wings.
#   Nom du Pokémon : Aerodactyl
# Phrase étudiée : A trainer was amazed to see a Snorlax eat an entire forest's worth of food.
#   Nom du Pokémon : Snorlax
# Phrase étudiée : It was rumored that an Articuno could create blizzards with its icy wings.
#   Nom du Pokémon : Articuno
# Phrase étudiée : People talked about a Zapdos that could summon thunderstorms with its electric powers.
#   Nom du Pokémon : Zapdos
# Phrase étudiée : A trainer encountered a Moltres that could set entire forests ablaze with its fiery wings.
#   Nom du Pokémon : Moltres
# Phrase étudiée : It was said that a Dratini could shed its skin to grow larger and stronger.
#   Nom du Pokémon : Dratini
# Phrase étudiée : A trainer discovered a Dragonair that could control the weather with its mystical powers.
#   Nom du Pokémon : Dragonair
# Phrase étudiée : It was rumored that a Dragonite could fly around the world in just sixteen hours.
#   Nom du Pokémon : Dragonite
# Phrase étudiée : People were amazed to see a Mewtwo create psychic storms with its mind.
#   Nom du Pokémon : Mewtwo
# Phrase étudiée : A trainer encountered a Mew that could transform into any pokémon and use any move.
#   Nom du Pokémon : Mew
# Phrase étudiée : It was said that a Chikorita could heal others with the leaf on its head.
#   Nom du Pokémon : Chikorita
# Phrase étudiée : A trainer found a Bayleef that could control plants with its leafy neck.
#   Nom du Pokémon : Bayleef
# Phrase étudiée : It was rumored that a Meganium could create healing fields with its flower.
#   Nom du Pokémon : Meganium
# Phrase étudiée : People talked about a Cyndaquil that could ignite its back with flames.
#   Nom du Pokémon : Cyndaquil
# Phrase étudiée : A trainer encountered a Quilava that could unleash fiery explosions with its body.
#   Nom du Pokémon : Quilava
# Phrase étudiée : It was said that a Typhlosion could create volcanic eruptions with its power.
#   Nom du Pokémon : Typhlosion
# Phrase étudiée : A trainer discovered a Totodile that could bite with incredible force.
#   Nom du Pokémon : Totodile
# Phrase étudiée : It was rumored that a Croconaw could snap its jaws with enough power to crush rocks.
#   Nom du Pokémon : Croconaw
# Phrase étudiée : People were amazed to see a Feraligatr that could swim through any body of water.
#   Nom du Pokémon : Feraligatr
# Phrase étudiée : A trainer encountered a Sentret that could stand on its tail to see long distances.
#   Nom du Pokémon : Sentret
# Phrase étudiée : It was said that a Furret could squeeze through any narrow space with its flexible body.
#   Nom du Pokémon : Furret
# Phrase étudiée : A trainer found a Hoothoot that could tell the time with its internal clock.
#   Nom du Pokémon : Hoothoot
# Phrase étudiée : It was rumored that a Noctowl could see in complete darkness with its sharp eyes.
#   Nom du Pokémon : Noctowl
# Phrase étudiée : People talked about a Ledyba that could communicate with others through its antennae.
#   Nom du Pokémon : Ledyba
# Phrase étudiée : A trainer encountered a Ledian that could unleash powerful punches with its armored fists.
#   Nom du Pokémon : Ledian
# Phrase étudiée : It was said that a Spinarak could spin webs that could trap any prey.
#   Nom du Pokémon : Spinarak
# Phrase étudiée : A trainer discovered an Ariados that could climb any surface with its sticky webs.
#   Nom du Pokémon : Ariados
# Phrase étudiée : It was rumored that a Crobat could fly silently and undetected through the night sky.
#   Nom du Pokémon : Crobat
# Phrase étudiée : People were amazed to see a Chinchou that could light up the ocean depths with its antennae.
#   Nom du Pokémon : Chinchou
# Phrase étudiée : A trainer encountered a Lanturn that could guide lost ships with its bright light.
#   Nom du Pokémon : Lanturn
# Phrase étudiée : It was said that a Pichu could generate sparks of electricity with its tiny body.
#   Nom du Pokémon : Pichu
# Phrase étudiée : A trainer found a Cleffa that could dance under the moonlight with its starry wings.
#   Nom du Pokémon : Cleffa
# Phrase étudiée : It was rumored that a Igglybuff could sing lullabies that could put anyone to sleep.
#   Nom du Pokémon : Igglybuff
# Phrase étudiée : People talked about a Togepi that could bring good luck to anyone who held it.
#   Nom du Pokémon : Togepi
# Phrase étudiée : A trainer encountered a Togetic that could fly through the sky with its angelic wings.
#   Nom du Pokémon : Togetic
# Phrase étudiée : It was said that a Natu could see into the future with its psychic powers.
#   Nom du Pokémon : Natu
# Phrase étudiée : A trainer discovered a Xatu that could predict events with its mystical visions.
#   Nom du Pokémon : Xatu
# Phrase étudiée : It was rumored that a Mareep could generate static electricity with its wool.
#   Nom du Pokémon : Mareep
# Phrase étudiée : People were amazed to see a Flaaffy that could store electricity in its fleece.
#   Nom du Pokémon : Flaaffy
# Phrase étudiée : A trainer encountered an Ampharos that could light up lighthouses with its tail.
#   Nom du Pokémon : Ampharos
# Phrase étudiée : It was said that a Bellossom could dance in flower fields with its graceful movements.
#   Nom du Pokémon : Bellossom
# Phrase étudiée : A trainer found a Marill that could create bubbles with its tail.
#   Nom du Pokémon : Marill
# Phrase étudiée : It was rumored that a Azumarill could swim through any body of water with its buoyant body.
#   Nom du Pokémon : Azumarill
# Phrase étudiée : People talked about a Sudowoodo that could mimic trees with its wooden body.
#   Nom du Pokémon : Sudowoodo
# Phrase étudiée : A trainer encountered a Politoed that could lead other Poliwhirl with its booming voice.
#   Nom du Pokémon : Politoed
#   Nom du Pokémon : Poliwhirl
# Phrase étudiée : It was said that a Hoppip could float on the wind with its light body.
#   Nom du Pokémon : Hoppip
# Phrase étudiée : A trainer discovered a Skiploom that could spread pollen with its flower.
#   Nom du Pokémon : Skiploom
# Phrase étudiée : It was rumored that a Jumpluff could travel on the wind with its cotton spores.
#   Nom du Pokémon : Jumpluff
# Phrase étudiée : People were amazed to see a Aipom that could use its tail like a hand.
#   Nom du Pokémon : Aipom
# Phrase étudiée : A trainer encountered a Sunkern that could absorb sunlight with its flower.
#   Nom du Pokémon : Sunkern
# Phrase étudiée : It was said that a Sunflora could follow the sun with its head.
#   Nom du Pokémon : Sunflora
# Phrase étudiée : A trainer found a Yanma that could fly with its dragonfly wings.
#   Nom du Pokémon : Yanma
# Phrase étudiée : It was rumored that a Wooper could regenerate its body with its slime.
#   Nom du Pokémon : Wooper
# Phrase étudiée : People talked about a Quagsire that could live in any body of water.
#   Nom du Pokémon : Quagsire
# Phrase étudiée : A trainer encountered a Espeon that could sense emotions with its psychic powers.
#   Nom du Pokémon : Espeon
# Phrase étudiée : It was said that a Umbreon could glow in the dark with its rings.
#   Nom du Pokémon : Umbreon
# Phrase étudiée : A trainer discovered a Murkrow that could steal shiny objects with its beak.
#   Nom du Pokémon : Murkrow
# Phrase étudiée : It was rumored that a Slowking could solve complex problems with its intelligence.
#   Nom du Pokémon : Slowking
# Phrase étudiée : People were amazed to see a Misdreavus that could cause mischief with its ghostly powers.
#   Nom du Pokémon : Misdreavus
# Phrase étudiée : A trainer encountered a Unown that could create illusions with its symbols.
#   Nom du Pokémon : Unown
# Phrase étudiée : It was said that a Wobbuffet could reflect any attack with its counter.
#   Nom du Pokémon : Wobbuffet
# Phrase étudiée : A trainer found a Girafarig that could see in two directions with its head.
#   Nom du Pokémon : Girafarig
# Phrase étudiée : It was rumored that a Pineco could explode when disturbed.
#   Nom du Pokémon : Pineco
# Phrase étudiée : People talked about a Forretress that could defend itself with its hard shell.
#   Nom du Pokémon : Forretress
# Phrase étudiée : A trainer encountered a Dunsparce that could burrow through the ground with its drill.
#   Nom du Pokémon : Dunsparce
# Phrase étudiée : It was said that a Gligar could glide through the air with its wings.
#   Nom du Pokémon : Gligar
# Phrase étudiée : A trainer discovered a Steelix that could tunnel through rock with its body.
#   Nom du Pokémon : Steelix
# Phrase étudiée : It was rumored that a Snubbull could scare away opponents with its fierce face.
#   Nom du Pokémon : Snubbull
# Phrase étudiée : People were amazed to see a Granbull that could bite with incredible force.
#   Nom du Pokémon : Granbull
# Phrase étudiée : A trainer encountered a Qwilfish that could inflate its body with poison spikes.
#   Nom du Pokémon : Qwilfish
# Phrase étudiée : It was said that a Scizor could slice through anything with its claws.
#   Nom du Pokémon : Scizor
# Phrase étudiée : A trainer found a Shuckle that could store berries in its shell.
#   Nom du Pokémon : Shuckle
# Phrase étudiée : It was rumored that a Heracross could lift objects many times its own weight.
#   Nom du Pokémon : Heracross
# Phrase étudiée : People talked about a Sneasel that could climb any surface with its claws.
#   Nom du Pokémon : Sneasel
# Phrase étudiée : A trainer encountered a Teddiursa that could find honey with its nose.
#   Nom du Pokémon : Teddiursa
# Phrase étudiée : It was said that a Ursaring could tear down trees with its strength.
#   Nom du Pokémon : Ursaring
# Phrase étudiée : A trainer discovered a Slugma that could live in lava with its fiery body.
#   Nom du Pokémon : Slugma
# Phrase étudiée : It was rumored that a Magcargo could melt anything with its heat.
#   Nom du Pokémon : Magcargo
# Phrase étudiée : People were amazed to see a Swinub that could find hot springs with its snout.
#   Nom du Pokémon : Swinub
# Phrase étudiée : A trainer encountered a Piloswine that could charge through snow with its tusks.
#   Nom du Pokémon : Piloswine
# Phrase étudiée : It was said that a Corsola could regenerate its branches with its coral body.
#   Nom du Pokémon : Corsola
# Phrase étudiée : A trainer found a Remoraid that could shoot water with its mouth.
#   Nom du Pokémon : Remoraid
# Phrase étudiée : It was rumored that a Octillery could ink its opponents with its mouth.
#   Nom du Pokémon : Octillery
# Phrase étudiée : People talked about a Delibird that could deliver presents with its bag.
#   Nom du Pokémon : Delibird
# Phrase étudiée : A trainer encountered a Mantine that could glide on the waves with its wings.
#   Nom du Pokémon : Mantine
# Phrase étudiée : It was said that a Skarmory could fly with its metallic wings.
#   Nom du Pokémon : Skarmory
# Phrase étudiée : A trainer discovered a Houndour that could track down prey with its scent.
#   Nom du Pokémon : Houndour
# Phrase étudiée : It was rumored that a Houndoom could unleash fiery blasts with its mouth.
#   Nom du Pokémon : Houndoom
# Phrase étudiée : People were amazed to see a Kingdra that could control the tides with its power.
#   Nom du Pokémon : Kingdra
# Phrase étudiée : A trainer encountered a Phanpy that could roll around with its trunk.
#   Nom du Pokémon : Phanpy
# Phrase étudiée : It was said that a Donphan could charge through anything with its body.
#   Nom du Pokémon : Donphan
# Phrase étudiée : A trainer found a Porygon2 that could adapt to any environment.
#   Nom du Pokémon : Porygon2
# Phrase étudiée : It was rumored that a Stantler could create illusions with its Stantler.
#   Nom du Pokémon : Stantler
#   Nom du Pokémon : Stantler
# Phrase étudiée : People talked about a Smeargle that could paint with its tail.
#   Nom du Pokémon : Smeargle
# Phrase étudiée : A trainer encountered a Tyrogue that could learn any fighting style.
#   Nom du Pokémon : Tyrogue
# Phrase étudiée : It was said that a Hitmontop could spin with its kicks.
#   Nom du Pokémon : Hitmontop
# Phrase étudiée : A trainer discovered a Smoochum that could blow icy kisses.
#   Nom du Pokémon : Smoochum
# Phrase étudiée : It was rumored that a Elekid could generate electricity with its plugs.
#   Nom du Pokémon : Elekid
# Phrase étudiée : People were amazed to see a Magby that could create fire with its mouth.
#   Nom du Pokémon : Magby
# Phrase étudiée : A trainer encountered a Miltank that could produce milk with its body.
#   Nom du Pokémon : Miltank
# Phrase étudiée : It was said that a Blissey could heal any wound with its egg.
#   Nom du Pokémon : Blissey
# Phrase étudiée : A trainer found a Raikou that could summon thunderstorms with its speed.
#   Nom du Pokémon : Raikou
# Phrase étudiée : It was rumored that a Entei could create volcanic eruptions with its roars.
#   Nom du Pokémon : Entei
# Phrase étudiée : People talked about a Suicune that could purify water with its touch.
#   Nom du Pokémon : Suicune
# Phrase étudiée : A trainer encountered a Larvitar that could eat rocks with its jaws.
#   Nom du Pokémon : Larvitar
# Phrase étudiée : It was said that a Pupitar could create hard shells with its body.
#   Nom du Pokémon : Pupitar
# Phrase étudiée : A trainer discovered a Tyranitar that could destroy mountains with its power.
#   Nom du Pokémon : Tyranitar
# Phrase étudiée : It was rumored that a Lugia could control the seas with its song.
#   Nom du Pokémon : Lugia
# Phrase étudiée : People were amazed to see a Ho-Oh that could bring life with its flames.
# Phrase étudiée : A trainer encountered a Celebi that could travel through time with its wings.
#   Nom du Pokémon : Celebi
# Phrase étudiée : It was said that a Treecko could climb any surface with its claws.
#   Nom du Pokémon : Treecko
# Phrase étudiée : A trainer found a Grovyle that could move through forests with its agility.
#   Nom du Pokémon : Grovyle
# Phrase étudiée : It was rumored that a Sceptile could control plants with its leaves.
#   Nom du Pokémon : Sceptile
# Phrase étudiée : People talked about a Torchic that could create fire with its body.
#   Nom du Pokémon : Torchic
# Phrase étudiée : A trainer encountered a Combusken that could unleash fiery kicks.
#   Nom du Pokémon : Combusken
# Phrase étudiée : It was said that a Blaziken could control flames with its power.
#   Nom du Pokémon : Blaziken
# Phrase étudiée : A trainer discovered a Mudkip that could create mud with its fins.
#   Nom du Pokémon : Mudkip
# Phrase étudiée : It was rumored that a Marshtomp could live in mud with its body.
#   Nom du Pokémon : Marshtomp
# Phrase étudiée : People were amazed to see a Swampert that could control water with its power.
#   Nom du Pokémon : Swampert
# Phrase étudiée : A trainer encountered a Poochyena that could track down prey with its scent.
#   Nom du Pokémon : Poochyena
# Phrase étudiée : It was said that a Mightyena could lead packs with its strength.
#   Nom du Pokémon : Mightyena
# Phrase étudiée : A trainer found a Zigzagoon that could find items with its nose.
#   Nom du Pokémon : Zigzagoon
# Phrase étudiée : It was rumored that a Linoone could run at high speeds with its body.
#   Nom du Pokémon : Linoone
# Phrase étudiée : People talked about a Wurmple that could evolve into different forms.
#   Nom du Pokémon : Wurmple
# Phrase étudiée : A trainer encountered a Silcoon that could spin silk with its body.
#   Nom du Pokémon : Silcoon
# Phrase étudiée : It was said that a Beautifly could spread pollen with its wings.
#   Nom du Pokémon : Beautifly
# Phrase étudiée : A trainer discovered a Cascoon that could harden its shell with its body.
#   Nom du Pokémon : Cascoon
# Phrase étudiée : It was rumored that a Dustox could release poison powder with its wings.
#   Nom du Pokémon : Dustox
# Phrase étudiée : People were amazed to see a Lotad that could float on water with its leaf.
#   Nom du Pokémon : Lotad
# Phrase étudiée : A trainer encountered a Lombre that could dance on water with its body.
#   Nom du Pokémon : Lombre
# Phrase étudiée : It was said that a Ludicolo could create rain with its dance.
#   Nom du Pokémon : Ludicolo
# Phrase étudiée : A trainer found a Seedot that could hang from trees with its thread.
#   Nom du Pokémon : Seedot
# Phrase étudiée : It was rumored that a Nuzleaf could trick opponents with its flute.
#   Nom du Pokémon : Nuzleaf
# Phrase étudiée : People talked about a Shiftry that could create wind with its fan.
#   Nom du Pokémon : Shiftry
# Phrase étudiée : A trainer encountered a Taillow that could fly at high speeds with its wings.
#   Nom du Pokémon : Taillow
# Phrase étudiée : It was said that a Swellow could perform aerial acrobatics with its body.
#   Nom du Pokémon : Swellow
# Phrase étudiée : A trainer discovered a Wingull that could carry items with its beak.
#   Nom du Pokémon : Wingull
# Phrase étudiée : It was rumored that a Pelipper could deliver items with its pouch.
#   Nom du Pokémon : Pelipper
# Phrase étudiée : People were amazed to see a Ralts that could sense emotions with its psychic powers.
#   Nom du Pokémon : Ralts
# Phrase étudiée : A trainer encountered a Kirlia that could dance with its psychic energy.
#   Nom du Pokémon : Kirlia
# Phrase étudiée : It was said that a Gardevoir could protect its trainer with its psychic power.
#   Nom du Pokémon : Gardevoir
# Phrase étudiée : A trainer found a Surskit that could skate on water with its feet.
#   Nom du Pokémon : Surskit
# Phrase étudiée : It was rumored that a Masquerain could create illusions with its antennae.
#   Nom du Pokémon : Masquerain
# Phrase étudiée : People talked about a Shroomish that could release poison spores with its head.
#   Nom du Pokémon : Shroomish
# Phrase étudiée : A trainer encountered a Breloom that could punch with its stretchy arms.
#   Nom du Pokémon : Breloom
# Phrase étudiée : It was said that a Slakoth could sleep for most of the day.
#   Nom du Pokémon : Slakoth
# Phrase étudiée : A trainer discovered a Vigoroth that could move at high speeds with its claws.
#   Nom du Pokémon : Vigoroth
# Phrase étudiée : It was rumored that a Slaking could unleash powerful attacks with its strength.
#   Nom du Pokémon : Slaking
# Phrase étudiée : People were amazed to see a Nincada that could burrow underground with its claws.
#   Nom du Pokémon : Nincada
# Phrase étudiée : A trainer encountered a Ninjask that could move at incredible speeds with its wings.
#   Nom du Pokémon : Ninjask
# Phrase étudiée : It was said that a Shedinja could float without moving with its shell.
#   Nom du Pokémon : Shedinja
# Phrase étudiée : A trainer found a Whismur that could emit loud noises with its voice.
#   Nom du Pokémon : Whismur
# Phrase étudiée : It was rumored that a Loudred could amplify its voice with its speakers.
#   Nom du Pokémon : Loudred
# Phrase étudiée : People talked about a Exploud that could create sonic booms with its voice.
#   Nom du Pokémon : Exploud
# Phrase étudiée : A trainer encountered a Makuhita that could punch with its powerful arms.
#   Nom du Pokémon : Makuhita
# Phrase étudiée : It was said that a Hariyama could throw opponents with its strength.
#   Nom du Pokémon : Hariyama
# Phrase étudiée : A trainer discovered a Nosepass that could point north with its nose.
#   Nom du Pokémon : Nosepass
# Phrase étudiée : It was rumored that a Skitty could chase its tail with its playful nature.
#   Nom du Pokémon : Skitty
# Phrase étudiée : People were amazed to see a Delcatty that could charm opponents with its beauty.
#   Nom du Pokémon : Delcatty
# Phrase étudiée : A trainer encountered a Sableye that could see in the dark with its eyes.
#   Nom du Pokémon : Sableye
# Phrase étudiée : It was said that a Mawile could bite with its large jaws.
#   Nom du Pokémon : Mawile
# Phrase étudiée : A trainer found an Aron that could protect itself with its hard armor.
#   Nom du Pokémon : Aron
# Phrase étudiée : It was rumored that a Lairon could crush rocks with its metal body.
#   Nom du Pokémon : Lairon
# Phrase étudiée : People talked about a Aggron that could destroy anything with its strength.
#   Nom du Pokémon : Aggron
# Phrase étudiée : A trainer encountered a Meditite that could meditate to increase its psychic power.
#   Nom du Pokémon : Meditite
# Phrase étudiée : It was said that a Medicham could unleash powerful kicks with its legs.
#   Nom du Pokémon : Medicham
# Phrase étudiée : A trainer discovered a Electrike that could generate electricity with its fur.
#   Nom du Pokémon : Electrike
# Phrase étudiée : It was rumored that a Manectric could control lightning with its power.
#   Nom du Pokémon : Manectric
# Phrase étudiée : People were amazed to see a Plusle that could cheer on its teammates.
#   Nom du Pokémon : Plusle
# Phrase étudiée : A trainer encountered a Minun that could support its teammates with its energy.
#   Nom du Pokémon : Minun
# Phrase étudiée : It was said that a Volbeat could communicate with light signals.
#   Nom du Pokémon : Volbeat
# Phrase étudiée : A trainer found a Illumise that could guide Volbeat with its light.
#   Nom du Pokémon : Illumise
#   Nom du Pokémon : Volbeat
# Phrase étudiée : It was rumored that a Roselia could release sweet scents with its flowers.
#   Nom du Pokémon : Roselia
# Phrase étudiée : People talked about a Gulpin that could swallow anything with its stretchy body.
#   Nom du Pokémon : Gulpin
# Phrase étudiée : A trainer encountered a Swalot that could digest anything with its stomach.
#   Nom du Pokémon : Swalot
# Phrase étudiée : It was said that a Carvanha could bite with its sharp teeth.
#   Nom du Pokémon : Carvanha
# Phrase étudiée : A trainer discovered a Sharpedo that could swim at high speeds with its body.
#   Nom du Pokémon : Sharpedo
# Phrase étudiée : It was rumored that a Wailmer could float on water with its large body.
#   Nom du Pokémon : Wailmer
# Phrase étudiée : People were amazed to see a Wailord that could swim through any ocean with its size.
#   Nom du Pokémon : Wailord
# Phrase étudiée : A trainer encountered a Numel that could store lava in its hump.
#   Nom du Pokémon : Numel
# Phrase étudiée : It was said that a Camerupt could erupt with its volcano body.
#   Nom du Pokémon : Camerupt
# Phrase étudiée : A trainer found a Torkoal that could burn coal with its shell.
#   Nom du Pokémon : Torkoal
# Phrase étudiée : It was rumored that a Spoink could bounce on its spring with its body.
#   Nom du Pokémon : Spoink
# Phrase étudiée : People talked about a Grumpig that could control pearls with its psychic power.
#   Nom du Pokémon : Grumpig
# Phrase étudiée : A trainer encountered a Spinda that could move in unpredictable patterns.
#   Nom du Pokémon : Spinda
# Phrase étudiée : It was said that a Trapinch could dig holes with its jaws.
#   Nom du Pokémon : Trapinch
# Phrase étudiée : A trainer discovered a Vibrava that could create sonic waves with its wings.
#   Nom du Pokémon : Vibrava
# Phrase étudiée : It was rumored that a Flygon could fly through sandstorms with its wings.
#   Nom du Pokémon : Flygon
# Phrase étudiée : People were amazed to see a Cacnea that could store water in its body.
#   Nom du Pokémon : Cacnea
# Phrase étudiée : A trainer encountered a Cacturne that could survive in deserts with its body.
#   Nom du Pokémon : Cacturne
# Phrase étudiée : It was said that a Swablu could fly with its cotton wings.
#   Nom du Pokémon : Swablu
# Phrase étudiée : A trainer found an Altaria that could sing with its beautiful voice.
#   Nom du Pokémon : Altaria
# Phrase étudiée : It was rumored that a Zangoose could fight with its sharp claws.
#   Nom du Pokémon : Zangoose
# Phrase étudiée : People talked about a Seviper that could poison opponents with its fangs.
#   Nom du Pokémon : Seviper
# Phrase étudiée : A trainer encountered a Lunatone that could control gravity with its psychic power.
#   Nom du Pokémon : Lunatone
# Phrase étudiée : It was said that a Solrock could generate solar energy with its body.
#   Nom du Pokémon : Solrock
# Phrase étudiée : A trainer discovered a Barboach that could sense earthquakes with its whiskers.
#   Nom du Pokémon : Barboach
# Phrase étudiée : It was rumored that a Whiscash could predict disasters with its instincts.
#   Nom du Pokémon : Whiscash
# Phrase étudiée : People were amazed to see a Corphish that could pinch with its claws.
#   Nom du Pokémon : Corphish
# Phrase étudiée : A trainer encountered a Crawdaunt that could crush opponents with its pincers.
#   Nom du Pokémon : Crawdaunt
# Phrase étudiée : It was said that a Baltoy could spin with its psychic energy.
#   Nom du Pokémon : Baltoy
# Phrase étudiée : A trainer found a Claydol that could create psychic barriers with its arms.
#   Nom du Pokémon : Claydol
# Phrase étudiée : It was rumored that a Lileep could sway in the water with its tentacles.
#   Nom du Pokémon : Lileep
# Phrase étudiée : People talked about a Cradily that could capture prey with its tentacles.
#   Nom du Pokémon : Cradily
# Phrase étudiée : A trainer encountered an Anorith that could slash with its claws.
#   Nom du Pokémon : Anorith
# Phrase étudiée : It was said that an Armaldo could protect itself with its hard shell.
#   Nom du Pokémon : Armaldo
# Phrase étudiée : A trainer discovered a Feebas that could survive in dirty water.
#   Nom du Pokémon : Feebas
# Phrase étudiée : It was rumored that a Milotic could calm anyone with its beauty.
#   Nom du Pokémon : Milotic
# Phrase étudiée : People were amazed to see a Castform that could change forms with the weather.
#   Nom du Pokémon : Castform
# Phrase étudiée : A trainer encountered a Kecleon that could change colors with its body.
#   Nom du Pokémon : Kecleon
# Phrase étudiée : It was said that a Shuppet could absorb emotions with its cloth.
#   Nom du Pokémon : Shuppet
# Phrase étudiée : A trainer found a Banette that could curse opponents with its grudge.
#   Nom du Pokémon : Banette
# Phrase étudiée : It was rumored that a Duskull could pass through walls with its ghostly body.
#   Nom du Pokémon : Duskull
# Phrase étudiée : People talked about a Dusclops that could see through anything with its eye.
#   Nom du Pokémon : Dusclops
# Phrase étudiée : A trainer encountered a Tropius that could fly with its leaf wings.
#   Nom du Pokémon : Tropius
# Phrase étudiée : It was said that a Chimecho could create calming sounds with its bell.
#   Nom du Pokémon : Chimecho
# Phrase étudiée : A trainer discovered an Absol that could sense disasters with its horn.
#   Nom du Pokémon : Absol
# Phrase étudiée : It was rumored that a Wynaut could endure any attack with its body.
#   Nom du Pokémon : Wynaut
# Phrase étudiée : People were amazed to see a Snorunt that could survive in snow with its body.
#   Nom du Pokémon : Snorunt
# Phrase étudiée : A trainer encountered a Glalie that could create ice with its body.
#   Nom du Pokémon : Glalie
# Phrase étudiée : It was said that a Spheal could roll around with its round body.
#   Nom du Pokémon : Spheal
# Phrase étudiée : A trainer found a Sealeo that could use its body to slide on ice.
#   Nom du Pokémon : Sealeo
# Phrase étudiée : It was rumored that a Walrein could break ice with its tusks.
#   Nom du Pokémon : Walrein
# Phrase étudiée : People talked about a Clamperl that could create pearls with its shell.
#   Nom du Pokémon : Clamperl
# Phrase étudiée : A trainer encountered a Huntail that could lure prey with its tail easily.
#   Nom du Pokémon : Huntail

# %%
# Maintenant, je vais transposer mon json formaté en data d'entrainement exploitable pour spacy
with open("larger_formatted_pokemon_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Transformer en format spaCy
TRAIN_DATA = []
for entry in data:
    text = entry["text"]
    entities = [(start, end, label) for start, end, label in entry["entities"]]
    TRAIN_DATA.append((text, {"entities": entities}))

print(TRAIN_DATA[:2])
# Out:
# [('Pikachu used Thunderbolt to defeat the wild Charmander.', {'entities': [(0, 7, 'POKEMON'), (44, 54, 'POKEMON')]}), ("Ash's favorite pokémon is Charizard because of its powerful Flamethrower.", {'entities': [(26, 35, 'POKEMON')]})]

# %%
# Je vais utiliser le modèle spacy
nlp=None
ner=None
try:
    # Attempt to load the model
    nlp = spacy.load("en_core_web_md")
    ner = nlp.get_pipe("ner")
    print("Model loaded successfully.")

except OSError as e:
    print(f"Error loading model: {e}")
    print("It seems the 'en_core_web_sm' model is not downloaded or not accessible.")
    print("Attempting to download the model...")
    try:
        # Download the model
        spacy.cli.download("en_core_web_sm")
        print("Model downloaded successfully.")
        # Load the model again after downloading
        nlp = spacy.load("en_core_web_sm")
        ner = nlp.get_pipe("ner")
        print("Model loaded successfully after download.")
    except Exception as download_error:
        print(f"Error downloading or loading the model: {download_error}")
        print("Please ensure you have an internet connection and try again.")
        print("You can also try downloading the model manually using the command:")
        print("python -m spacy download en_core_web_sm")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Model loaded successfully.

# %%
# Check if nlp and ner are defined before using them
if nlp is not None and ner is not None:
    # Ici j'ajoute le label pokémon
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

# %%
# Entraînement du modèle
optimizer = nlp.create_optimizer()
optimizer.learn_rate = 0.005

n_iter = 10
losses = {}

# Initialize losses for each pipe in the pipeline
for pipe_name in nlp.pipe_names:
    losses[pipe_name] = 0.0

for i in range(n_iter):
    random.shuffle(TRAIN_DATA)
    batches = spacy.util.minibatch(TRAIN_DATA, size=8)
    total_loss = 0.0
    for batch in batches:
        for text, annotations in batch:
            doc = nlp.make_doc(text)
            example = spacy.training.Example.from_dict(doc, annotations)
            nlp.update([example], drop=0.3, losses=losses, sgd=optimizer)

    # Calculate the average loss for this iteration
    iteration_loss = sum(losses.values()) / len(losses) if len(losses) > 0 else 0.0
    print(f"Losses at iteration {i}: {losses} - Average Loss: {iteration_loss}")

    # Reset losses for the next iteration
    for pipe_name in losses:
        losses[pipe_name] = 0.0
        
nlp.to_disk("C:/Users/moqp3/Desktop/catho/S2/NLP/nlp/tp4/NER_results")
# Out:
# Losses at iteration 0: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 116.66741919643233} - Average Loss: 19.444569866072055
# Losses at iteration 1: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 51.219086370127194} - Average Loss: 8.536514395021198
# Losses at iteration 2: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 45.45839686851091} - Average Loss: 7.576399478085151
# Losses at iteration 3: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 25.00497204273036} - Average Loss: 4.167495340455059
# Losses at iteration 4: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 20.64320806789741} - Average Loss: 3.440534677982902
# Losses at iteration 5: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 23.600893454693942} - Average Loss: 3.9334822424489904
# Losses at iteration 6: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 22.660201835470996} - Average Loss: 3.7767003059118327
# Losses at iteration 7: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 20.995846859264244} - Average Loss: 3.499307809877374
# Losses at iteration 8: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 13.898694363950533} - Average Loss: 2.3164490606584223
# Losses at iteration 9: {'tok2vec': 0.0, 'tagger': 0.0, 'parser': 0.0, 'attribute_ruler': 0.0, 'lemmatizer': 0.0, 'ner': 8.503193615277095} - Average Loss: 1.4171989358795158

# %%
import spacy
import json

def visualize_ner_predictions(trained_model, sentence_to_predict, list_of_pokemon_names):
    try:
        trained_nlp = spacy.load(trained_model)
    except OSError as error:
        print(f"Error loading model from {trained_model}: {error}")
        print("Please ensure the model path is correct and the model is saved there.")
        return

    processed_sentence = trained_nlp(sentence_to_predict)
    # Filter out entities that are not in all_pokemon_names
    valid_ents = [entity for entity in processed_sentence.ents if entity.text in list_of_pokemon_names]
    processed_sentence.ents = tuple(valid_ents)

    if not processed_sentence.ents:
        print("No entities found in the text.")
        return

    print("Entities found:")
    for entity in processed_sentence.ents:
        print(f"  - {entity.text} ({entity.label_})")

    colors = {"POKEMON": "linear-gradient(90deg, #aa9cfc, #fc9ce7)"}
    options = {"ents": ["POKEMON"], "colors": colors}
    displacy.render(processed_sentence, style="ent", jupyter=True, options=options)

    highlighted_text = ""
    last_end = 0
    for token in processed_sentence:
        if token.text in list_of_pokemon_names and token.ent_type_ != "POKEMON":
            highlighted_text += sentence_to_predict[last_end:token.idx] + f"<mark style='background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;'>{token.text}</mark>"

        last_end = token.idx + len(token.text) #Force last_end to update every loop.

    if last_end <= len(sentence_to_predict):
        highlighted_text += sentence_to_predict[last_end:]

    if highlighted_text != sentence_to_predict:
        highlighted_text+="\n<mark style='background:#d64b4e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;'>Pokémon names highlighted (not detected as entities):</mark>"
        display(HTML(data=highlighted_text))

# Example usage (replace with your actual model path and text)
model_path = "C:/Users/moqp3/Desktop/catho/S2/NLP/nlp/tp4/NER_results"  # Replace with the path to your saved model
test_text = "Dragonite and Charizard are my favorite pokémon. I also like Pachirisu and Snorlax. What about you? I saw a wild Bulbasaur and a shiny Pikachu. I also saw a wild Pidgeot."
# Load all_pokemon_names if you haven't already
if 'all_pokemon_names' not in locals() and 'all_pokemon_names' not in globals():
    with open("all_pokemons.json", "r", encoding="utf-8") as file:
        all_pokemon_names = json.load(file)

visualize_ner_predictions(model_path, test_text, all_pokemon_names)
# Out:
# Entities found:
#   - Dragonite (POKEMON)
#   - Charizard (POKEMON)
#   - Pachirisu (POKEMON)
#   - Snorlax (POKEMON)
#   - Bulbasaur (POKEMON)
#   - Pikachu (POKEMON)
#   - Pidgeot (POKEMON)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dragonite
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POKEMON</span>
# </mark>
#  and
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charizard
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POKEMON</span>
# </mark>
#  are my favorite pokémon. I also like
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pachirisu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POKEMON</span>
# </mark>
#  and
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Snorlax
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POKEMON</span>
# </mark>
# . What about you? I saw a wild
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bulbasaur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POKEMON</span>
# </mark>
#  and a shiny
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pikachu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POKEMON</span>
# </mark>
# . I also saw a wild
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pidgeot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POKEMON</span>
# </mark>
# .</div></span>
# <mark style='background:#d64b4e; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;'>Pokémon names highlighted (not detected as entities):</mark>

# %%
# The "Pokémon names highlighted (not detected as entities)" section is about names that:
# Are present in all_pokemon_names: This means they are known pokémon names according to the full list.
# Are NOT recognized as "POKEMON" entities by the trained NER model: this indicates that the model failed to identify them as such during its processing of the text.
